# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import paris_2025 as p
import matplotlib.pyplot as plt

# %%
co2 = p.tracers.get_co2_measurement()

# %%
co2
# Out:
# <xarray.Dataset> Size: 19MB
# Dimensions:    (time: 17544, station: 39)
# Coordinates:
#     height     (station) float64 312B ...
#     altitude   (station) float64 312B ...
#     latitude   (station) float64 312B ...
#     longitude  (station) float64 312B ...
#     x          (station) float64 312B ...
#     y          (station) float64 312B ...
#     code       (station) <U7 1kB ...
#     type       (station) <U9 1kB ...
#   * time       (time) datetime64[ns] 140kB 2023-01-01 ... 2024-12-31T23:00:00
#   * station    (station) <U12 2kB 'AND_60.0' 'CDS_34.0' ... 'VES_47.0'
# Data variables:
#     co2        (time, station) float64 5MB ...
#     stdev      (time, station) float64 5MB ...
#     nbpoints   (time, station) float64 5MB ...
#     flag       (time, station) <U1 3MB ...

# %%
co2.co2.plot.imshow()
plt.title("CO2 Concentration available in Paris")
plt.xticks(rotation=90)
pass

# %%
co2.co2.mean("time").plot.scatter()

# %%
plt.scatter(
    x=co2.x,
    y=co2.y,
    s=100,
    c=co2.co2.mean("time"),
    edgecolor="black",
    alpha=0.7,
    cmap="viridis",
)
plt.title("Average CO2 Concentration in Paris")
plt.xlabel("x (m)")
plt.ylabel("y (m)")
plt.colorbar(label="CO2 Concentration (ppm)")
plt.show()
